# %%
import numpy as np
import pandas as pd
from IPython.display import display
from tqdm import tqdm
from collections import Counter
import ast

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sb

from sklearn.feature_extraction.text import TfidfVectorizer
from textblob import TextBlob
import scipy.stats as stats

from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.manifold import TSNE

from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook
output_notebook()

# %matplotlib inline

import xgboost
from xgboost import XGBClassifier
from xgboost import plot_tree
from sklearn.model_selection import train_test_split
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## 여행지 키워드 전처리

# %%
tour = pd.read_csv("./final_data/전체_final_data_edit.csv", encoding = 'utf-8-sig')

# 각 행의 키워드를 문자열 형태로 만들어주기 위해 인덱스 초기화(인덱스 활용 접근)
tour.reset_index()

# 각 행의 키워드들을 문자열화
for i in range(tour.shape[0]):  
    keyword = tour.loc[i, 'keyword'].replace("'관광지'", "")
    keyword = keyword.replace('[', '').replace(']', '').replace("'", "")
    keyword = keyword.replace(' ', '').split(',')
    keyword = ' '.join(keyword)
    tour.loc[i, 'keyword'] = keyword
    if tour.loc[i, 'keyword'] == '':
        tour.loc[i, 'keyword'] = np.nan

tour.head()
# Out:
#               name  region           tel              keyword  \
# 0        (구)강경노동조합  충남 논산시  041-746-5412    건축여행  근대건축물 등록문화재
# 1   (구)인천일본제58은행지점   인천 중구  032-760-6474        교과서속여행 문화재 역사
# 2         (구)태백등기소  강원 태백시           166                  NaN
# 3     (구)한일은행 강경지점  충남 논산시  041-746-5412  건축여행  근대건축물 역사 역사공부
# 4  (전)광주 성거사지 오층석탑   광주 남구  062-607-2333      탑 보물 역사공부 역사관광지
#
#                                                photo  \
# 0  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 1  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 2  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 3  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 4  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
#
#                       address        lat         lon
# 0  충청남도 논산시 강경읍 옥녀봉로27번길 30-5  36.160849  127.014602
# 1         인천광역시 중구 신포로23번길 77  37.472859  126.621154
# 2           강원도 태백시 하장성 1길 14  37.102615  129.020972
# 3    충청남도 논산시 강경읍 계백로167번길 50  36.162130  127.015154
# 4        광주광역시 남구 천변좌로338번길 7  35.147999  126.908710

# %%
tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14060 entries, 0 to 14059
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     14060 non-null  object
#  1   region   14060 non-null  object
#  2   tel      13904 non-null  object
#  3   keyword  13782 non-null  object
#  4   photo    14060 non-null  object
#  5   address  14060 non-null  object
#  6   lat      14060 non-null  float64
#  7   lon      14060 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 878.9+ KB

# %%
# tfidf 벡터에 없는 키워드만 가진 여행지 제거하기 위한 작업
tour['tel'].fillna(value=0, inplace=True)

# %%
# tfidf 벡터에 없는 키워드만 가진는 모든 topic의 값이 null 값이므로 제거
tour.dropna(inplace=True)

# %%
tour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13782 entries, 0 to 14059
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     13782 non-null  object
#  1   region   13782 non-null  object
#  2   tel      13782 non-null  object
#  3   keyword  13782 non-null  object
#  4   photo    13782 non-null  object
#  5   address  13782 non-null  object
#  6   lat      13782 non-null  float64
#  7   lon      13782 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 969.0+ KB

# %%
# 여행지 제거 후 인덱스 초기화
tour.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## gensim

# %%
from gensim import corpora
import gensim
import pyLDAvis.gensim

tour.reset_index()

documents = []
for i in range(tour.shape[0]):
    tour.loc[i, 'keyword'] = tour.loc[i, 'keyword']
    documents.append(tour.loc[i, 'keyword'].split())
    
dictionary = corpora.Dictionary(documents)
corpus = [dictionary.doc2bow(text) for text in documents]
print(dictionary)
for c in corpus:
    print(c)

# %%
NUM_TOPICS = 7
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary, passes=15, random_state = 77)
topics = ldamodel.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.161*"자연" + 0.124*"레포츠" + 0.024*"자연좋은곳" + 0.023*"생태관광지"')
# (1, '0.164*"역사" + 0.160*"역사공부" + 0.145*"역사관광지" + 0.135*"역사를품은곳"')
# (2, '0.112*"불교" + 0.106*"역사" + 0.105*"사찰" + 0.105*"불교문화"')
# (3, '0.095*"가족과함께" + 0.055*"아이와함께" + 0.052*"경치좋은곳" + 0.040*"남녀노소"')
# (4, '0.098*"쇼핑" + 0.033*"사진찍기좋은곳" + 0.031*"친구와함께" + 0.025*"사진찍기"')
# (5, '0.156*"가족과함께" + 0.074*"나들이" + 0.061*"아이와함께" + 0.046*"쇼핑"')
# (6, '0.148*"문화시설" + 0.090*"아이와함께" + 0.067*"가족과함께" + 0.040*"교과서속여행"')

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1486021402526943365290468096"></div>
# <script type="text/javascript">
#
# var ldavis_el1486021402526943365290468096_data = {"mdsDat": {"x": [-0.31986719530368823, 0.19008416232857644, 0.19167445546994583, 0.009438577275548863, 0.20208387894012056, -0.2542696672473934, -0.019144211463109996], "y": [-0.21138679139469918, 0.021840976242492472, -0.1732546296165341, 0.28968580510822955, -0.09676518369011963, 0.0786225372291266, 0.09125728612150463], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [21.111526489257812, 16.74089241027832, 16.02887725830078, 13.967672348022461, 13.918128967285156, 11.992840766906738, 6.240072250366211]}, "tinfo": {"Term": ["\uc5ed\uc0ac\uacf5\ubd80", "\uc5ed\uc0ac", "\uc5ed\uc0ac\uad00\uad11\uc9c0", "\uc5ed\uc0ac\ub97c\ud488\uc740\uacf3", "\uc790\uc5f0", "\ubb38\ud654\uc2dc\uc124", "\uac00\uc871\uacfc\ud568\uaed8", "\uc5ed\uc0ac\ubb38\ud654\uc7ac", "\ub808\ud3ec\uce20", "\ubd88\uad50", "\uc5ed\uc0ac\uc18d", "\uc0ac\ucc30", "\ubd88\uad50\ubb38\ud654", "\uc0ac\ucc30\uc5ec\ud589", "\uc544\uc774\uc640\ud568\uaed8", "\uc1fc\ud551", "\ub098\ub4e4\uc774", "\uc790\uc5f0\uc18d\uc73c\ub85c", "\uc790\uc5f0\ud658\uacbd", "\uacbd\uce58\uc88b\uc740\uacf3", "\ub098\ud640\ub85c\uc5ec\ud589", "\uac00\ubcfc\ub9cc\ud55c\uacf3", "\uc0b0\ucc45\ud558\uae30\uc88b\uc740\uacf3", "\ubcf5\ud569\ubb38\ud654\uacf5\uac04", "\ubc15\ubb3c\uad00", "\ub0a8\ub140\ub178\uc18c", "\uad50\uacfc\uc11c\uc18d\uc5ec\ud589", "\ub370\uc774\ud2b8\ucf54\uc2a4", "\uc0b0\ucc45\uae38", "\uba39\uac70\ub9ac", "\uc5ed\uc0ac\uacf5\ubd80", "\uc5ed\uc0ac\uad00\uad11\uc9c0", "\uc5ed\uc0ac\ub97c\ud488\uc740\uacf3", "\uc5ed\uc0ac\ubb38\ud654\uc7ac", "\uc5ed\uc0ac\uc18d", "\uc5ed\uc0ac\uc18d\uc73c\ub85c", "\ubb38\ud654\uc7ac", "\uc11c\uc6d0", "\uc5ed\uc0ac\uad00\uad11", "\uc5ed\uc0ac\ubb38\ud654", "\ubb38\ud654\uc7ac\uc790\ub8cc", "\uae30\ub150\ubb3c", "\uc0ac\uc801", "\uc608\uc220", "\ubb34\uc7a5\uc560", "\ubcf4\ubb3c", "\uc5ed\uc0ac\uc5ec\ud589", "\uc5b4\ucd0c\uccb4\ud5d8\ub9c8\uc744", "\uace0\ud0dd", "\uc2a4\ud0a4\uc7a5", "\ub4f1\ub85d\ubb38\ud654\uc7ac", "\ubbfc\uc18d\ubb38\ud654\uc7ac", "\uc5ed\uc0ac\ubb38\ud654\uad00\uad11", "\uc5ed\uc0ac\ud0d0\ubc29", "\uc218\uc0c1\ub808\ud3ec\uce20", "\ub09a\uc2dc\uccb4\ud5d8", "\uc131\uc9c0\uc21c\ub840", "\uadfc\ub300\uc5ed\uc0ac", "\uccad\uc18c\ub144\uc218\ub828\uad00", "\ud5a5\uad50", "\uc5ed\uc0ac", "\uc5ed\uc0ac\uc774\uc57c\uae30", "\uad50\uacfc\uc11c\uc18d\uc5ec\ud589", "\ubd88\uc0c1", "\uacbd\uce58\uc88b\uc740\uacf3", "\uac00\ubcfc\ub9cc\ud55c\uacf3", "\uc0b0\ucc45\ud558\uae30\uc88b\uc740\uacf3", "\uc0b0\ucc45\uae38", "\uc0b0\ucc45\ud558\uae30", "\ubc14\ub2e4\uacbd\uce58", "\uc0b0\ucc45\ucf54\uc2a4", "\uacc4\uace1", "\uc5ec\ub984\uc5ec\ud589", "\ubc14\ub2e4\ub0b4\uc74c", "\uc5ec\ub984\ud53c\uc11c\uc9c0", "\uacac\ud559", "\ucea0\ud551\uc7a5", "\uacbd\uce58\uc5ec\ud589", "\ub4f1\uc0b0\ub85c", "\uc5ec\ud589", "\uc5b8\ud0dd\ud2b8\uad00\uad11\uc9c0_100\uc120", "\uc628\ucc9c", "\uac74\uac15\uc5ec\ud589", "\uc2a4\ud30c", "\uaf43\uc5ec\ud589", "\ub9db\uc9d1", "\uc5ec\ub984\ud734\uac00", "\ud53c\uc11c", "\ubd80\ubaa8\ub2d8\uacfc\ud568\uaed8", "\uad00\uad11\ub450\ub808", "\ubd04\uaf43\uc5ec\ud589", "\uc57c\uc678\ucea0\ud551\uc7a5", "\uc624\ud1a0\ucea0\ud551\uc7a5", "\uba39\uc790\uace8\ubaa9", "\uacf5\uc6d0", "\ub4dc\ub77c\uc774\ube0c\uc5ec\ud589", "\uccb4\ud5d8\ud559\uc2b5", "\ub0a8\ub140\ub178\uc18c", "\uc0b0\uc5c5\uad00\uad11", "\uc5f0\uc778\uacfc\ud568\uaed8", "\uac77\uae30\uae38", "\uac00\uc871\uacfc\ud568\uaed8", "\uc774\uc0c9\uccb4\ud5d8", "\uc544\uc774\uc640\ud568\uaed8", "\ub808\ud3ec\uce20", "\uac77\uae30\uc5ec\ud589", "\uad50\uc721\uc5ec\ud589", "\uc790\uc5f0\uc88b\uc740\uacf3", "\ubb38\ud654\uc2dc\uc124", "\ubcf5\ud569\ubb38\ud654\uacf5\uac04", "\ubc15\ubb3c\uad00", "\ubb38\ud654\uacf5\uac04", "\uc2e4\ub0b4\uc5ec\ud589\uc9c0", "\uc5f4\ub9b0\ubb38\ud654\uacf5\uac04", "\uc2e4\ub0b4\uc5ec\ud589", "\ubb38\ud654\uc608\uc220", "\ubbf8\uc220\uad00", "\ub2f9\uc77c\uce58\uae30\uc5ec\ud589", "\uad50\uc721\ud504\ub85c\uadf8\ub7a8", "\ubb38\ud654\ud589\uc0ac", "\uae30\u ...

# %%
def make_topictable_per_doc(ldamodel, corpus):
    topic_table = pd.DataFrame()

    # 몇 번째 문서인지를 의미하는 문서 번호와 해당 문서의 토픽 비중을 한 줄씩 꺼내온다.
    for i, topic_list in enumerate(ldamodel[corpus]):
        doc = topic_list[0] if ldamodel.per_word_topics else topic_list            
        doc = sorted(doc, key=lambda x: (x[1]), reverse=True)
        # 각 문서에 대해서 비중이 높은 토픽순으로 토픽을 정렬한다.
        # EX) 정렬 전 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (10번 토픽, 5%), (12번 토픽, 21.5%), 
        # Ex) 정렬 후 0번 문서 : (2번 토픽, 48.5%), (8번 토픽, 25%), (12번 토픽, 21.5%), (10번 토픽, 5%)
        # 48 > 25 > 21 > 5 순으로 정렬이 된 것.

        # 모든 문서에 대해서 각각 아래를 수행
        for j, (topic_num, prop_topic) in enumerate(doc): #  몇 번 토픽인지와 비중을 나눠서 저장한다.
            if j == 0:  # 정렬을 한 상태이므로 가장 앞에 있는 것이 가장 비중이 높은 토픽
                topic_table = topic_table.append(pd.Series([int(topic_num), round(prop_topic,4), topic_list]), ignore_index=True)
                # 가장 비중이 높은 토픽과, 가장 비중이 높은 토픽의 비중과, 전체 토픽의 비중을 저장한다.
            else:
                break
    return(topic_table)

# %%
topictable = make_topictable_per_doc(ldamodel, corpus)

topictable.columns = ['topic', 'topic_rate', 'topic_list']
topictable
# Out:
#        topic  topic_rate                                         topic_list
# 0        4.0      0.5358  [(0, 0.03572094), (1, 0.28555897), (2, 0.03572...
# 1        1.0      0.7855  [(0, 0.03571455), (1, 0.785476), (2, 0.0357532...
# 2        1.0      0.4285  [(0, 0.028573046), (1, 0.42854363), (2, 0.0286...
# 3        1.0      0.6289  [(0, 0.028584184), (1, 0.62892115), (2, 0.2281...
# 4        6.0      0.7679  [(0, 0.017858913), (1, 0.017858911), (2, 0.017...
# ...      ...         ...                                                ...
# 13777    6.0      0.8928  [(0, 0.01785726), (1, 0.01785726), (2, 0.01785...
# 13778    5.0      0.3496  [(0, 0.017866297), (1, 0.017863857), (2, 0.267...
# 13779    3.0      0.8283  [(0, 0.028834809), (1, 0.02857842), (2, 0.0285...
# 13780    3.0      0.8282  [(0, 0.028666003), (1, 0.028578162), (2, 0.028...
# 13781    4.0      0.5237  [(0, 0.023816055), (1, 0.02381605), (2, 0.0238...
#
# [13782 rows x 3 columns]

# %%
topictable['topic'].value_counts()
# Out:
# 0.0    3139
# 1.0    2665
# 3.0    2360
# 6.0    2256
# 5.0    1576
# 2.0    1125
# 4.0     661
# Name: topic, dtype: int64

# %%
tour_topic = pd.concat([tour, topictable], axis = 1)

# %%
tour_topic.head()
# Out:
#               name  region           tel                          keyword  \
# 0        (구)강경노동조합  충남 논산시  041-746-5412                건축여행  근대건축물 등록문화재
# 1   (구)인천일본제58은행지점   인천 중구  032-760-6474                    교과서속여행 문화재 역사
# 2     (구)한일은행 강경지점  충남 논산시  041-746-5412              건축여행  근대건축물 역사 역사공부
# 3  (전)광주 성거사지 오층석탑   광주 남구  062-607-2333                  탑 보물 역사공부 역사관광지
# 4         (주) 교보문고  서울 종로구     1544-1900  서점 도서관 도심여행 문화시설 문화행사 사계절 아이와함께
#
#                                                photo  \
# 0  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 1  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 2  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 3  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# 4  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
#
#                       address        lat         lon  topic  topic_rate  \
# 0  충청남도 논산시 강경읍 옥녀봉로27번길 30-5  36.160849  127.014602    4.0      0.5358
# 1         인천광역시 중구 신포로23번길 77  37.472859  126.621154    1.0      0.7855
# 2    충청남도 논산시 강경읍 계백로167번길 50  36.162130  127.015154    1.0      0.4285
# 3        광주광역시 남구 천변좌로338번길 7  35.147999  126.908710    1.0      0.6289
# 4              서울특별시 종로구 종로 1  37.573054  127.016590    6.0      0.7679
#
#                                           topic_list
# 0  [(0, 0.03572094), (1, 0.28555897), (2, 0.03572...
# 1  [(0, 0.03571455), (1, 0.785476), (2, 0.0357532...
# 2  [(0, 0.028573046), (1, 0.42854363), (2, 0.0286...
# 3  [(0, 0.028584184), (1, 0.62892115), (2, 0.2281...
# 4  [(0, 0.017858913), (1, 0.017858911), (2, 0.017...

# %%
tour_topic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13782 entries, 0 to 13781
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        13782 non-null  object
#  1   region      13782 non-null  object
#  2   tel         13782 non-null  object
#  3   keyword     13782 non-null  object
#  4   photo       13782 non-null  object
#  5   address     13782 non-null  object
#  6   lat         13782 non-null  float64
#  7   lon         13782 non-null  float64
#  8   topic       13782 non-null  float64
#  9   topic_rate  13782 non-null  float64
#  10  topic_list  13782 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 1.2+ MB

# %%
# 키워드 입력
documents_input = []
keyword_input = input().split()

keyword_str = ""
for i in range(len(dictionary)):
    for k in keyword_input:
        if k in dictionary[i]:
            keyword_str += dictionary[i] + " "

keyword_input = keyword_str.split()
documents_input.append(keyword_input)
corpus_input = [dictionary.doc2bow(text) for text in documents_input]
topictable_input = make_topictable_per_doc(ldamodel, corpus_input)
topictable_input.columns = ['topic', 'topic_rate', 'topic_list']
topictable_input
# Out:
# 바다
#    topic  topic_rate                                         topic_list
# 0    3.0      0.5222  [(0, 0.2587787), (3, 0.5222136), (5, 0.1700086...

# %%
topic_result = topictable_input['topic'][0]
tour_topic_keyword = tour_topic[tour_topic['topic'] == topic_result]

# %%
tour_topic.set_index('name', inplace = True)

# %%
tour_topic.head()
# Out:
#                  region           tel                          keyword  \
# name
# (구)강경노동조합        충남 논산시  041-746-5412                건축여행  근대건축물 등록문화재
# (구)인천일본제58은행지점    인천 중구  032-760-6474                    교과서속여행 문화재 역사
# (구)한일은행 강경지점     충남 논산시  041-746-5412              건축여행  근대건축물 역사 역사공부
# (전)광주 성거사지 오층석탑   광주 남구  062-607-2333                  탑 보물 역사공부 역사관광지
# (주) 교보문고         서울 종로구     1544-1900  서점 도서관 도심여행 문화시설 문화행사 사계절 아이와함께
#
#                                                              photo  \
# name
# (구)강경노동조합        https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# (구)인천일본제58은행지점   https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# (구)한일은행 강경지점     https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# (전)광주 성거사지 오층석탑  https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
# (주) 교보문고         https://cdn.visitkorea.or.kr/img/call?cmd=VIEW...
#
#                                     address        lat         lon  topic  \
# name
# (구)강경노동조합        충청남도 논산시 강경읍 옥녀봉로27번길 30-5  36.160849  127.014602    4.0
# (구)인천일본제58은행지점          인천광역시 중구 신포로23번길 77  37.472859  126.621154    1.0
# (구)한일은행 강경지점       충청남도 논산시 강경읍 계백로167번길 50  36.162130  127.015154    1.0
# (전)광주 성거사지 오층석탑        광주광역시 남구 천변좌로338번길 7  35.147999  126.908710    1.0
# (주) 교보문고                     서울특별시 종로구 종로 1  37.573054  127.016590    6.0
#
#                  topic_rate                                         topic_list
# name
# (구)강경노동조합            0.5358  [(0, 0.03572094), (1, 0.28555897), (2, 0.03572...
# (구)인천일본제58은행지점       0.7855  [(0, 0.03571455), (1, 0.785476), (2, 0.0357532...
# (구)한일은행 강경지점         0.4285  [(0, 0.028573046), (1, 0.42854363), (2, 0.0286...
# (전)광주 성거사지 오층석탑      0.6289  [(0, 0.028584184), (1, 0.62892115), (2, 0.2281...
# (주) 교보문고             0.7679  [(0, 0.017858913), (1, 0.017858911), (2, 0.017...

# %%
tour_topic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13782 entries, (구)강경노동조합 to 힐튼양복점
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   region      13782 non-null  object
#  1   tel         13782 non-null  object
#  2   keyword     13782 non-null  object
#  3   photo       13782 non-null  object
#  4   address     13782 non-null  object
#  5   lat         13782 non-null  float64
#  6   lon         13782 non-null  float64
#  7   topic       13782 non-null  float64
#  8   topic_rate  13782 non-null  float64
#  9   topic_list  13782 non-null  object
# dtypes: float64(4), object(6)
# memory usage: 1.2+ MB

# %%
tour_topic.to_csv("./final_data/LDA_gensim_topic.csv", mode='w', encoding ='utf-8-sig')
